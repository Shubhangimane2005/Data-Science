# %% [markdown]
# ## Loading the dataset

# %% [markdown]
# 1.1 Loading a sample dataset

# %%
from sklearn import datasets

# %%
digits = datasets.load_digits()
print(digits.data)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
features = digits.data

# %%
target = digits.target

# %%
features[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %% [markdown]
# ### Creating a Simulated Dataset

# %% [markdown]
# ### Regression

# %%
# load library
from sklearn.datasets import make_regression

# %%
# generate features matrix, target vector, and the true coefficients
features, target, coefficients = make_regression(
    n_samples=100,
    n_features=3,
    n_informative=3,
    n_targets=1,
    noise=0.0,
    coef=True,
    random_state=1
)

# %%
# view feature matrix and target vector
print("Feature Matrix \n{}".format(features[:3]))
print("Target Vector \n{}".format(target[:3]))
# Out:
# Feature Matrix
# [[ 1.29322588 -0.61736206 -0.11044703]
#  [-2.793085    0.36633201  1.93752881]
#  [ 0.80186103 -0.18656977  0.0465673 ]]
# Target Vector
# [-10.37865986  25.5124503   19.67705609]

# %%
print("Coefficients:", coefficients)
# Out:
# Coefficients: [44.19042807 98.97517077 58.15774073]

# %%
# visualize regression dataset
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.scatter(features[:, 0], target, color="blue", alpha=0.6)
plt.title("Regression Dataset (Feature 1 vs Target)")
plt.xlabel("Feature 1")
plt.ylabel("Target")
plt.show()

# %% [markdown]
# ### Classification

# %%
# load library
from sklearn.datasets import make_classification

# %%
# generate features matrix and target vector
features, target = make_classification(
    n_samples=100,
    n_features=3,
    n_informative=3,
    n_redundant=0,
    n_classes=2,
    weights=[0.25, 0.75],
    random_state=1
)

# %%
# view feature matrix and target vector
print("Feature Matrix \n{}".format(features[:3]))
print("Target Vector \n{}".format(target[:3]))
# Out:
# Feature Matrix
# [[ 1.06354768 -1.42632219  1.02163151]
#  [ 0.23156977  1.49535261  0.33251578]
#  [ 0.15972951  0.83533515 -0.40869554]]
# Target Vector
# [1 0 0]

# %%
# visualize classification dataset
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.scatter(features[:, 0], features[:, 1], c=target, cmap="bwr", alpha=0.7)
plt.title("Classification Dataset (Feature 1 vs Feature 2)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# ### Clustering

# %%
# load library
from sklearn.datasets import make_blobs

# %%
# generate feature matrix and target vector
features, target = make_blobs(
    n_samples=100,
    n_features=2,
    centers=3,
    cluster_std=0.5,
    shuffle=True,
    random_state=1
)

# %%
# view feature matrix and target vector
print("Feature Matrix \n{}".format(features[:3]))
print("Target Vector \n{}".format(target[:3]))
# Out:
# Feature Matrix
# [[ -1.22685609   3.25572052]
#  [ -9.57463218  -4.38310652]
#  [-10.71976941  -4.20558148]]
# Target Vector
# [0 1 1]

# %%
# visualize clustering dataset (blobs)
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.scatter(features[:, 0], features[:, 1], c=target, cmap="viridis", alpha=0.7)
plt.title("Clustering Dataset (make_blobs)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# ### Loading an Csv File

# %%
import pandas as pd

# Load CSV
df_csv = pd.read_csv("Housing.csv")
print(df_csv.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ### Loading an Excel File

# %%
import pandas as pd

# Load Excel
df_excel = pd.read_excel("Cancer.xlsx")
print(df_excel.head())
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %% [markdown]
# ### Loading an json File

# %%
import pandas as pd

# Load JSON
df_json = pd.read_json("indian_medicine_data.json")
print(df_json.head())
# Out:
#    id                      name  price(₹) Is_discontinued  \
# 0   1  Augmentin 625 Duo Tablet    223.42           FALSE
# 1   2       Azithral 500 Tablet    132.36           FALSE
# 2   3          Ascoril LS Syrup    118.00           FALSE
# 3   4      Allegra 120mg Tablet    218.81           FALSE
# 4   5            Avil 25 Tablet     10.96           FALSE
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 15 tablets
#
#       short_composition1          short_composition2
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# 1   Azithromycin (500mg)
# ...

# %% [markdown]
# ### Quering a sql database

# %%
import pandas as pd
from sqlalchemy import create_engine, inspect

# create connection
db_connection = create_engine('sqlite:///sqlite-sakila.db')

# using inspector to list tables
insp = inspect(db_connection)
print(insp.get_table_names())

# load data
df = pd.read_sql_query('SELECT * FROM actor', db_connection)

df.head()
# Out:
# ['actor', 'address', 'category', 'city', 'country', 'customer', 'film', 'film_actor', 'film_category', 'film_text', 'inventory', 'language', 'payment', 'rental', 'staff', 'store']
#    actor_id first_name     last_name          last_update
# 0         1   PENELOPE       GUINESS  2021-03-06 15:51:59
# 1         2       NICK      WAHLBERG  2021-03-06 15:51:59
# 2         3         ED         CHASE  2021-03-06 15:51:59
# 3         4   JENNIFER         DAVIS  2021-03-06 15:51:59
# 4         5     JOHNNY  LOLLOBRIGIDA  2021-03-06 15:51:59
